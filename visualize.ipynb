# %%
import matplotlib.pyplot as plt
import glob
import json
import seaborn as sns
import pandas as pd
import numpy as np

# %%
# json_files = sorted(glob.glob('./vis/.json'))
json_file = 'vis/learning_data-1.json'

# %%
learning_data = []
# for file in json_files:
with open(json_file, 'r') as f:
    episode_data = json.load(f)
    learning_data.extend(episode_data)

# %%
df = pd.DataFrame(learning_data)

# %%
# df.head

# %%
# df[df['epsilon'] > 0.15]

# %%
df['episode'] = df.index // 10

# %%
# avg_df = df.groupby('episode').agg({'reward': 'mean', 'loss': 'mean'}).reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 avg_df = df.groupby('episode').agg({'reward': 'mean', 'loss': 'mean'}).reset_index()
#
# File ~/miniconda3/envs/mario/lib/python3.9/site-packages/pandas/core/groupby/generic.py:1432, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1429     kwargs["engine_kwargs"] = engine_kwargs
#    1431 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 1432 result = op.agg()
#    1433 if not is_dict_like(func) and result is not None:
#    1434     # GH #52849
#    1435     if not self.as_index and is_list_like(func):
#
# File ~/miniconda3/envs/mario/lib/python3.9/site-packages/pandas/core/apply.py:190, in Apply.agg(self)
#     187     return self.apply_str()
#     189 if is_dict_like(func):
# --> 190     return self.agg_dict_like()
#     191 elif is_list_like(func):
# ...

# %%
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['reward'], label='Reward')
plt.plot(df.index, df['loss'], label='Loss')
plt.xlabel('Step')
plt.ylabel('Value')
plt.title('Reward and Loss Over Time')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['epsilon'], label='epsilon')
plt.xlabel('Step')
plt.ylabel('Value')
plt.title('Reward and Loss Over Time')
plt.legend()
plt.show()
